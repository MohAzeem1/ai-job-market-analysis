# %%
print("Allah is great")
# Out:
# Allah is great

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ai_job_market.csv')

# %%
df.head()
# Out:
#    job_id                  job_title company_size company_industry    country  \
# 0       1                AI Engineer      Startup           Retail     Canada
# 1       2  Machine Learning Engineer          MNC       Technology  Australia
# 2       3  Machine Learning Engineer          MNC       Technology    Germany
# 3       4           Business Analyst      Startup       Healthcare    Germany
# 4       5             Data Scientist          MNC       Healthcare    Germany
#
#   remote_type experience_level  years_experience education_level  \
# 0      Remote           Senior                 2          Master
# 1      Hybrid              Mid                 0        Bachelor
# 2      Onsite              Mid                14          Master
# 3      Remote              Mid                 9          Master
# 4      Hybrid              Mid                 5          Master
#
#    skills_python  skills_sql  skills_ml  skills_deep_learning  skills_cloud  \
# ...

# %%
df.shape
# Out:
# (10345, 19)

# %%
df.columns
# Out:
# Index(['job_id', 'job_title', 'company_size', 'company_industry', 'country',
#        'remote_type', 'experience_level', 'years_experience',
#        'education_level', 'skills_python', 'skills_sql', 'skills_ml',
#        'skills_deep_learning', 'skills_cloud', 'salary', 'job_posting_month',
#        'job_posting_year', 'hiring_urgency', 'job_openings'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10345 entries, 0 to 10344
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   job_id                10345 non-null  int64
#  1   job_title             10345 non-null  object
#  2   company_size          10345 non-null  object
#  3   company_industry      10345 non-null  object
#  4   country               10345 non-null  object
#  5   remote_type           10345 non-null  object
#  6   experience_level      10345 non-null  object
#  7   years_experience      10345 non-null  int64
#  8   education_level       10345 non-null  object
#  9   skills_python         10345 non-null  int64
#  10  skills_sql            10345 non-null  int64
#  11  skills_ml             10345 non-null  int64
#  12  skills_deep_learning  10345 non-null  int64
#  13  skills_cloud          10345 non-null  int64
#  14  salary                10345 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# job_id                  0
# job_title               0
# company_size            0
# company_industry        0
# country                 0
# remote_type             0
# experience_level        0
# years_experience        0
# education_level         0
# skills_python           0
# skills_sql              0
# skills_ml               0
# skills_deep_learning    0
# skills_cloud            0
# salary                  0
# job_posting_month       0
# job_posting_year        0
# hiring_urgency          0
# job_openings            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#              job_id  years_experience  skills_python    skills_sql  \
# count  10345.000000      10345.000000   10345.000000  10345.000000
# mean    5173.000000          6.950507       0.493088      0.503045
# std     2986.488601          4.320054       0.499976      0.500015
# min        1.000000          0.000000       0.000000      0.000000
# 25%     2587.000000          3.000000       0.000000      0.000000
# 50%     5173.000000          7.000000       0.000000      1.000000
# 75%     7759.000000         11.000000       1.000000      1.000000
# max    10345.000000         14.000000       1.000000      1.000000
#
#           skills_ml  skills_deep_learning  skills_cloud        salary  \
# count  10345.000000          10345.000000  10345.000000   10345.00000
# mean       0.507878              0.498018      0.511455  113438.22726
# std        0.499962              0.500020      0.499893   31389.20106
# min        0.000000              0.000000      0.000000   45083.00000
# ...

# %%
df.drop(columns = 'job_id', inplace = True)

# %%
df.shape
# Out:
# (10345, 18)

# %%
df.head(3)
# Out:
#                    job_title company_size company_industry    country  \
# 0                AI Engineer      Startup           Retail     Canada
# 1  Machine Learning Engineer          MNC       Technology  Australia
# 2  Machine Learning Engineer          MNC       Technology    Germany
#
#   remote_type experience_level  years_experience education_level  \
# 0      Remote           Senior                 2          Master
# 1      Hybrid              Mid                 0        Bachelor
# 2      Onsite              Mid                14          Master
#
#    skills_python  skills_sql  skills_ml  skills_deep_learning  skills_cloud  \
# 0              0           0          0                     1             0
# 1              1           1          1                     0             1
# 2              1           0          1                     0             1
#
#    salary  job_posting_month  job_posting_year hiring_urgency  job_openings
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Business Analyst             1773
# AI Engineer                  1742
# Machine Learning Engineer    1740
# Data Analyst                 1711
# Data Scientist               1703
# Data Engineer                1676
# Name: count, dtype: int64

# %%
df['job_title'].unique()
# Out:
# array(['AI Engineer', 'Machine Learning Engineer', 'Business Analyst',
#        'Data Scientist', 'Data Analyst', 'Data Engineer'], dtype=object)

# %%
plt.figure(figsize = (16,6))
sns.histplot(df['job_title'], bins = 30, kde = True)
plt.show()

# %%
plt.figure(figsize = (16,6))
sns.countplot(x = 'job_title', hue = 'company_size', data = df)
plt.show()

# %%
plt.figure(figsize = (16,6))
sns.countplot(x = 'job_title', hue = 'company_industry', data = df)
plt.xticks(rotation = 30)
plt.show()

# %%
plt.figure(figsize = (16,6))
sns.countplot(x = 'job_title', hue = 'country', data = df, order = df['job_title'].value_counts().index)
plt.show()

# %%
plt.figure(figsize = (16,6))
sns.countplot(x = 'job_title', hue = 'remote_type', data = df)
plt.show()

# %%
plt.figure(figsize = (16,6))
sns.countplot(x = 'job_title', hue = 'experience_level', data = df)
plt.show()

# %%
plt.figure(figsize = (16,6))
sns.countplot(x = 'job_title', hue = 'years_experience', data = df)
plt.show()

# %%
plt.figure(figsize = (16,6))
sns.countplot(x = 'job_title', hue = 'education_level', data = df)
plt.show()

# %%
features = ['company_size', 'company_industry', 'country', 'remote_type', 'experience_level']

# %%
for i, col in enumerate(features, 1):
    plt.figure(figsize = (20,15))
    plt.subplot(3,2,i)
    sns.countplot(x = 'job_title', hue = col, data = df)
    plt.xticks(rotation = 30)
    plt.title(f"Job Title vs {col}")
    plt.tight_layout()
    plt.show()

# %%
df.columns
# Out:
# Index(['job_title', 'company_size', 'company_industry', 'country',
#        'remote_type', 'experience_level', 'years_experience',
#        'education_level', 'skills_python', 'skills_sql', 'skills_ml',
#        'skills_deep_learning', 'skills_cloud', 'salary', 'job_posting_month',
#        'job_posting_year', 'hiring_urgency', 'job_openings'],
#       dtype='object')

# %%
plt.figure(figsize = (16,6))
sns.histplot(df['salary'], bins = 30, kde = True)
plt.title("Salary Distribution")
plt.show()

# %%
plt.figure(figsize = (16,6))
sns.boxplot(x = 'job_title', y= 'salary', data = df)
plt.title('Salary vs Job Title')
plt.show()

# %%
sns.boxplot(x = 'experience_level', y = 'job_title', data = df)
plt.show()

# %%
sns.scatterplot(x = 'years_experience', y = 'salary', hue = 'job_title',  data = df)
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.lmplot(x= 'years_experience', y = 'salary', col = 'job_title', data = df, height = 4, aspect = 1)
plt.show()

# %%
sns.boxplot(x = 'country', y = 'salary', data = df)
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.heatmap(df.corr(numeric_only = True), annot = True, cmap = 'coolwarm')
plt.show()

# %%
plt.figure(figsize = (16,6))
sns.boxplot(x = 'job_title', y = 'salary', data = df)
plt.show()

# %%
df_model = df.copy()

# %%
df_model = pd.get_dummies(df_model, drop_first = True)

# %%
df.shape, df_model.shape
# Out:
# ((10345, 18), (10345, 37))

# %%
df.head(3)
# Out:
#                    job_title company_size company_industry    country  \
# 0                AI Engineer      Startup           Retail     Canada
# 1  Machine Learning Engineer          MNC       Technology  Australia
# 2  Machine Learning Engineer          MNC       Technology    Germany
#
#   remote_type experience_level  years_experience education_level  \
# 0      Remote           Senior                 2          Master
# 1      Hybrid              Mid                 0        Bachelor
# 2      Onsite              Mid                14          Master
#
#    skills_python  skills_sql  skills_ml  skills_deep_learning  skills_cloud  \
# 0              0           0          0                     1             0
# 1              1           1          1                     0             1
# 2              1           0          1                     0             1
#
#    salary  job_posting_month  job_posting_year hiring_urgency  job_openings
# ...

# %%
df_model.head(3)
# Out:
#    years_experience  skills_python  skills_sql  skills_ml  \
# 0                 2              0           0          0
# 1                 0              1           1          1
# 2                14              1           0          1
#
#    skills_deep_learning  skills_cloud  salary  job_posting_month  \
# 0                     1             0  158322                  6
# 1                     0             1  163666                 11
# 2                     0             1  158556                  3
#
#    job_posting_year  job_openings  ...  country_UK  country_USA  \
# 0              2024             4  ...       False        False
# 1              2026             9  ...       False        False
# 2              2026             9  ...       False        False
#
#    remote_type_Onsite  remote_type_Remote  experience_level_Mid  \
# 0               False                True                 False
# 1               False               False                  True
# ...

# %%
x = df_model.drop('salary', axis  = 1)
y = df_model['salary']

# %%
x.shape, y.shape
# Out:
# ((10345, 36), (10345,))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((8276, 36), (2069, 36), (8276,), (2069,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mse = mean_squared_error(y_test , y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
mse, mae, r2
# Out:
# (8105087.557497197, 2448.5489013807455, 0.991859873412664)

# %%
from sklearn.metrics import accuracy_score

# %%
df.corr(numeric_only= True)['salary'].sort_values(ascending = False)
# Out:
# salary                  1.000000
# skills_deep_learning    0.242504
# skills_ml               0.232621
# skills_cloud            0.153725
# skills_python           0.009536
# job_openings            0.005715
# job_posting_year        0.003028
# skills_sql             -0.003473
# years_experience       -0.013266
# job_posting_month      -0.013555
# Name: salary, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(max_depth = 5)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5)

# %%
y_pred_rf = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
r2 = r2_score(y_test, y_pred_rf)

# %%
r2
# Out:
# 0.7312532218083945

# %%
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)

# %%
mse, mae
# Out:
# (8105087.557497197, 2448.5489013807455)

# %%
model = RandomForestRegressor(n_estimators = 200, max_depth = 10, min_samples_split = 5, random_state=42)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, min_samples_split=5, n_estimators=200,
#                       random_state=42)

# %%
y_pred_rf = model.predict(x_test)

# %%
r2_rf = r2_score(y_test, y_pred_rf)
r2_rf
# Out:
# 0.9387748342893801

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model , x, y, cv = 5, scoring = 'r2')
scores, scores.mean()
# Out:
# (array([0.92994377, 0.93513331, 0.94094448, 0.94248793, 0.92946859]),
#  np.float64(0.9355956174548619))

# %%
importance = model.feature_importances_
features = x.columns

# %%
pd.Series(importance, index = features).sort_values(ascending = False)
# Out:
# experience_level_Senior                0.328880
# job_title_Machine Learning Engineer    0.154474
# experience_level_Mid                   0.108144
# company_size_MNC                       0.080862
# skills_deep_learning                   0.066430
# skills_ml                              0.058159
# job_title_Data Engineer                0.043199
# job_title_Data Analyst                 0.037802
# job_title_Data Scientist               0.037134
# job_title_Business Analyst             0.030320
# skills_cloud                           0.028527
# years_experience                       0.004046
# job_posting_month                      0.003972
# job_openings                           0.003318
# job_posting_year                       0.002684
# education_level_Master                 0.000895
# education_level_PhD                    0.000846
# skills_python                          0.000789
# country_Germany                        0.000778
# remote_type_Onsite                     0.000755
# ...

# %%
import pickle
pickle.dump(model, open("model.pkl", "wb"))

# %%
import pickle

# Save model
pickle.dump(model, open("model.pkl", "wb"))

# Save columns
pickle.dump(x.columns, open("columns.pkl", "wb"))
